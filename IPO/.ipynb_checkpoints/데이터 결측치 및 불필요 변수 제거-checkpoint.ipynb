# %% [markdown]
# # 장기적으로 필요한 것
# * train file 들을 따로 분류해서 저장하고 가지면서 운영할 필요가 있어보임 공모가 1,3,6 트레이딩 정보포함 3,6
# * 현재 빠져 있는 것 종속변수 주가수익률
# * traiding 에서 쓰일 per pbr
# * 시총규모별로 나누기 함수 만들기

# %%
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta
from datetime import datetime
from dateutil.parser import parse
import pickle
from Module import Preprocessing

# %% [markdown]
# # 파일 읽어옴

# %%
F = pd.read_csv('Data/KQ_Finance.csv',thousands=',')

# %%
IPOcoms = F['Name'].unique()
F.set_index(['Name','Item'],inplace = True)

# %% [markdown]
# # 분모 분자로 재무지표들 계산하기

# %%
for i in IPOcoms:
    F.loc[(i,'매출총이익률'),:] = F.loc[(i,'매출총이익'),:] / F.loc[(i,'매출액'),:]
    F.loc[(i,'영업이익률'),:] = F.loc[(i,'영업이익'),:] / F.loc[(i,'매출액'),:]
    F.loc[(i,'ROE'),:] = F.loc[(i,'당기순이익'),:] / F.loc[(i,'자본총계'),:]
    F.loc[(i,'유동비율'),:] = F.loc[(i,'유동자산'),:] / F.loc[(i,'유동부채'),:]
    F.loc[(i,'당좌비율'),:] = F.loc[(i,'당좌자산'),:] / F.loc[(i,'유동부채'),:]
    F.loc[(i,'부채비율'),:] = F.loc[(i,'부채총계'),:] / F.loc[(i,'자본총계'),:]
    F.loc[(i,'이자보상배율'),:] = F.loc[(i,'영업이익'),:] / F.loc[(i,'이자비용'),:]
    F.loc[(i,'매출채권회전율'),:] = F.loc[(i,'매출액'),:] / F.loc[(i,'매출채권및기타채권'),:]
    F.loc[(i,'재고자산회전율'),:] = F.loc[(i,'매출액'),:] / F.loc[(i,'재고자산'),:]

# %%
for i in IPOcoms:
    F.loc[(i,'매출액증가율'),:] = calUp(F.loc[(i,'매출액'),:])
    F.loc[(i,'영업이익증가율'),:] = calUp(F.loc[(i,'영업이익'),:])
# Out:
# <ipython-input-29-c50165044131>:4: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (Series[i+1] - Series[i]) / Series[i]

# %%
F.to_csv('Data/KQ_CalFin.csv')

# %% [markdown]
# # 확인이 어려운 무상증자 기업 제거

# %%
X_train= pd.read_csv('CleanData/KQ_all.csv')
X_train.set_index('종목명',inplace = True)

# %%
f = open('Data/CA_increase.txt', 'r', encoding='UTF8')
line_num = 1
line = f.readline()
CA_coms = []
while line:
    com = line.replace('무상증자','')
    com = com.replace('\n','')
    com = com[:-1]
    CA_coms.append(com)
    line = f.readline()
    line_num += 1
f.close()

# %%
X_train.drop(CA_coms,inplace = True)

# %% [markdown]
# # 확정적으로 drop 시킬 컬럼들_애초에 안만드는 방향으로

# %%
cols = ['상장유형','공모가','상장주식수','경쟁률']
X_train.drop(cols ,axis =1 , inplace =True)

# %% [markdown]
# #  Null 확인

# %%
X_train['NullCount']  = X_train.isnull().sum(axis = 1)
nullcounts = X_train['NullCount'].unique()
X_train.columns
# Out:
# Index(['상장일', '공모 시가총액', '매출총이익률', '영업이익률', 'ROE', '유동비율', '당좌비율', '부채비율',
#        '이자보상배율', '매출채권회전율', '재고자산회전율', '매출액증가율', '영업이익증가율', 'IPO_PER',
#        'IPO_PBR', 'IPO_EV/EBITDA', '1개월 후 PER', '3개월 후 PER', '1개월 후 PBR',
#        '3개월 후 PBR', '1개월 후 EV/EBITDA', '3개월 후 EV/EBITDA', '1개월 평균 거래량회전율',
#        '1개월 평균 일중변동률', '1개월 평균 개인 매도수량 비중', '1개월 평균 개인 매수수량 비중', '1개월 시가총액회전율',
#        '3개월 평균 거래량회전율', '3개월 평균 일중변동률', '3개월 평균 개인 매도수량 비중',
#        '3개월 평균 개인 매수수량 비중', '3개월 시가총액회전율', '1년전 대비 시장 회전율', '1년 전 대비 시장수익률',
#        '1년 전 대비 광의통화 증감률', '1년 전 대비 고객예탁금 증감률', '1달 후 시장 회전율', '1달 후 시장수익률',
#        '1달 후 광의통화 증감률', '1달 후 고객예탁금 증감률', '3달 후 시장 회전율', '3달 후 시장수익률',
#        '3달 후 광의통화 증감률', '3달 후 고객예탁금 증감률', '상장일 기준 국고3년시장금리', '공모가 대비 1개월 수익률',
#        '공모가 대비 3개월 수익률', '공모가 대비 6개월 수익률', '1_3_수익률', '3_6_수익률', 'Cat',
#        'NullCount'],
#       dtype='object')

# %%
X_train.isnull().sum()
# Out:
# 상장일                    0
# 공모 시가총액                0
# 매출총이익률                24
# 영업이익률                 24
# ROE                   18
# 유동비율                  20
# 당좌비율                  26
# 부채비율                  18
# 이자보상배율                21
# 매출채권회전율               34
# 재고자산회전율              128
# 매출액증가율                66
# 영업이익증가율               55
# IPO_PER               17
# IPO_PBR               18
# IPO_EV/EBITDA         19
# 1개월 후 PER             40
# 3개월 후 PER             39
# 1개월 후 PBR             41
# 3개월 후 PBR             40
# 1개월 후 EV/EBITDA       41
# 3개월 후 EV/EBITDA       40
# 1개월 평균 거래량회전율          0
# 1개월 평균 일중변동률           0
# 1개월 평균 개인 매도수량 비중      0
# 1개월 평균 개인 매수수량 비중      0
# 1개월 시가총액회전율            0
# 3개월 평균 거래량회전율          0
# 3개월 평균 일중변동률           0
# 3개월 평균 개인 매도수량 비중      0
# 3개월 평균 개인 매수수량 비중      0
# 3개월 시가총액회전율            0
# 1년전 대비 시장 회전율          0
# 1년 전 대비 시장수익률          0
# 1년 전 대비 광의통화 증감률       0
# 1년 전 대비 고객예탁금 증감률      0
# 1달 후 시장 회전율            0
# 1달 후 시장수익률             0
# 1달 후 광의통화 증감률          0
# 1달 후 고객예탁금 증감률         0
# 3달 후 시장 회전율            0
# 3달 후 시장수익률             0
# 3달 후 광의통화 증감률          0
# 3달 후 고객예탁금 증감률         0
# 상장일 기준 국고3년시장금리        0
# 공모가 대비 1개월 수익률         0
# 공모가 대비 3개월 수익률         0
# 공모가 대비 6개월 수익률         0
# 1_3_수익률                0
# 3_6_수익률                0
# Cat                    0
# NullCount              0
# dtype: int64

# %%
Drop_After1_PBR = X_train[~X_train['1개월 후 PBR'].isnull().values]
Drop_After1_EBI = Drop_After1_PBR[~Drop_After1_PBR['1개월 후 EV/EBITDA'].isnull().values]
Drop_After1_EBI.isnull().sum()

# %% [markdown]
# # 재고자산 회전률& 당좌비율 & 이자보상배율 열 drop

# %%
Drop_After_inven = Drop_After1_EBI.drop(['당좌비율','이자보상배율','재고자산회전율'],axis =1 )
Drop_After_inven.isnull().sum()

# %% [markdown]
# # 최종 Null있어서 못쓰는 것들 제거

# %%
Drop_After_profit = Drop_After_inven[~Drop_After_inven['매출총이익률'].isnull().values]
Drop_After_profit.isnull().sum()

# %%
Drop_After_margin = Drop_After_profit[~Drop_After_profit['매출액증가율'].isnull().values]
Drop_After_margin = Drop_After_margin[~Drop_After_margin['매출채권회전율'].isnull().values]
Drop_After_margin = Drop_After_margin[~Drop_After_margin['유동비율'].isnull().values]
Drop_After_margin.isnull().sum()

# %%
Drop_After_margin.shape
# Out:
# (622, 49)

# %% [markdown]
# # 안쓰는 재무지표 최종 drop (상관관계 이슈)

# %%
FinalForm = Drop_After_margin.drop(['영업이익률','ROE','매출채권회전율','영업이익증가율'],axis = 1)

# %% [markdown]
# # 변수최종선정 끝

# %% [markdown]
# # 아래는 남은 Null들의 특징 찾는 것

# %%
X_train[X_train['NullCount'] == 6]
# Out:
#                   상장일       공모 시가총액    매출총이익률     영업이익률       ROE      유동비율  \
# 종목명
# 한스바이오메드    2009-10-09  4.271434e+10  0.440620  0.146855  0.121473  4.930205
# 스틸플라워      2009-10-27  1.755000e+11  0.335741  0.245251  0.246599  1.149502
# 비츠로셀       2009-10-28  6.972006e+10  0.314269  0.179471  0.385187  2.285652
# 상상인인더스트리   2009-11-06  2.730420e+10  0.170502  0.080481  0.168392  0.939685
# 동방선기       2009-11-10  2.400000e+10  0.193551  0.106861  0.263424  0.800293
# 에이프로젠 H&G  2009-11-13  1.875000e+10  0.266875  0.139822  0.669725  2.413849
# 이원컴포텍      2009-12-01  1.000000e+10  0.153736  0.067143  0.154984  1.531044
# 에스티팜       2016-06-23  5.360480e+11  0.371359  0.249700  0.227184  0.884986
# 로스웰        2016-06-30  2.905000e+11  0.359629  0.235591  0.272134  2.327658
# 피앤씨테크      2016-07-04  6.626532e+10  0.343523  0.232344  0.240433  3.750414
# 바이오리더스     2016-07-07  1.853150e+11  0.297201 -3.411235 -3.356855  2.288368
# 위니아딤채      2016-07-14  1.639580e+11  0.266036  0.037710  0.230036  0.944661
# 장원테크       2016-07-15  1.057880e+11  0.178420  0.128767  0.533637  0.890477
# 폴라리스웍스     2016-07-20  2.613318e+10  0.066537 -0.000937 -0.053572  0.634881
# 우리손에프앤지    2016-07-27  1.351580e+11  0.261292  0.169859  0.158837  0.772470
# 엠아이텍       2018-11-29  1.235530e+11  0.456010  0.081405  0.109836  4.240717
# 윙입푸드       2018-11-30  8.081819e+10  0.398416  0.285876  0.373113  2.055521
# 에코캡        2018-12-05  6.114696e+10  0.169280  0.060474  0.077298  1.269201
# 대유에이피      2018-12-07  3.265200e+10  0.076985  0.039022  0.267864  0.689667
# 이노메트리      2018-12-12  1.254530e+11  0.271105  0.140703  0.187303  1.962120
#
#                당좌비율      부채비율        이자보상배율    매출채권회전율  ...  3달 후 광의통화 증감률  \
# 종목명                                                     ...
# 한스바이오메드    3.769862  0.220829   37.46564154   2.258524  ...       0.022633
# 스틸플라워      0.451439  1.035477   10.72298128  10.492944  ...       0.022633
# 비츠로셀       1.493957  0.499764   13.93142393   7.601998  ...       0.022633
# 상상인인더스트리   0.244175  3.724633   2.253971682  10.251805  ...       0.014759
# 동방선기       0.338877  0.954499   6.503070944   8.648056  ...       0.014759
# 에이프로젠 H&G  2.077332  1.162007   16.98197235   4.498125  ...       0.014759
# 이원컴포텍      1.204755  0.685618   109.8368145  19.842534  ...       0.019965
# 에스티팜       0.265147  1.095776   7.814979035   8.298574  ...       0.027898
# 로스웰        2.104691  0.619912   12.05751057   1.497065  ...       0.020899
# 피앤씨테크      3.316877  0.328262   428.0096916   5.043469  ...       0.020899
# 바이오리더스     2.004162  0.718105   -21.2789986   1.894953  ...       0.020899
# 위니아딤채      0.649174  3.085566   8.301905606   6.084392  ...       0.020899
# 장원테크       0.615405  1.027244   20.59590206  15.060345  ...       0.020899
# 폴라리스웍스     0.481648  3.054563  -0.032613161   6.705886  ...       0.020899
# 우리손에프앤지    0.304011  1.588372   4.637768065   9.436304  ...       0.020899
# 엠아이텍       2.897358  0.588338     5.1488139   4.191672  ...       0.020929
# 윙입푸드       1.935585  0.541576    332.573944  10.293653  ...       0.013928
# 에코캡        0.986393  1.326112   6.385212208   3.600375  ...       0.013928
# 대유에이피      0.429992  1.932302   10.95578724  12.566186  ...       0.013928
# 이노메트리      1.928434  0.810381   38.04990193   4.003160  ...       0.013928
#
#            3달 후 고객예탁금 증감률  상장일 기준 국고3년시장금리  공모가 대비 1개월 수익률  공모가 대비 3개월 수익률  \
# 종목명
# 한스바이오메드          0.002490             4.36       -0.189091       -0.200000
# 스틸플라워            0.058240             4.54       -0.029630        0.037037
# 비츠로셀            -0.004843             4.51       -0.163636        0.038182
# 상상인인더스트리         0.073089             4.46       -0.398413       -0.356349
# 동방선기             0.061170             4.47       -0.187500       -0.180000
# 에이프로젠 H&G        0.003701             4.27       -0.098000        0.295000
# 이원컴포텍            0.021547             4.05        0.232500        0.862500
# 에스티팜            -0.016322             1.34        0.758621        0.827586
# 로스웰             -0.081129             1.25        0.014063       -0.040625
# 피앤씨테크           -0.121295             1.22       -0.049020       -0.040196
# 바이오리더스          -0.072548             1.21       -0.183333       -0.482000
# 위니아딤채           -0.087461             1.21       -0.098529       -0.260294
# 장원테크            -0.073648             1.22       -0.202857       -0.360000
# 폴라리스웍스          -0.057285             1.22        0.267797        0.135593
# 우리손에프앤지          0.000592             1.22        0.056561       -0.038462
# 엠아이텍             0.112100             1.89       -0.282222       -0.070000
# 윙입푸드             0.124949             1.90       -0.302500        0.145000
# 에코캡              0.066252             1.90       -0.109524       -0.114286
# 대유에이피            0.096307             1.83        0.720000        0.720000
# 이노메트리            0.048762             1.80       -0.080769        0.105769
#
#            공모가 대비 6개월 수익률   1_3_수익률   3_6_수익률  Cat  NullCount
# 종목명
# 한스바이오메드         -0.285455 -0.013453 -0.106818    3          6
# 스틸플라워            0.085185  0.068702  0.046429    3          6
# 비츠로셀            -0.125455  0.241304 -0.157618    3          6
# 상상인인더스트리        -0.363492  0.069921 -0.011097    2          6
# 동방선기            -0.137500  0.009231  0.051829    3          6
# 에이프로젠 H&G        0.400000  0.435698  0.081081    3          6
# 이원컴포텍            0.137500  0.511156 -0.389262    5          6
# 에스티팜             0.539655  0.039216 -0.157547    5          6
# 로스웰             -0.146875 -0.053929 -0.110749    4          6
# 피앤씨테크           -0.115686  0.009278 -0.078652    3          6
# 바이오리더스          -0.478000 -0.365714  0.007722    3          6
# 위니아딤채           -0.325735 -0.179445 -0.088469    3          6
# 장원테크            -0.430286 -0.197133 -0.109821    2          6
# 폴라리스웍스           0.033898 -0.104278 -0.089552    5          6
# 우리손에프앤지         -0.083710 -0.089936 -0.047059    4          6
# 엠아이텍             0.088889  0.295666  0.170848    2          6
# 윙입푸드            -0.002500  0.641577 -0.128821    2          6
# 에코캡             -0.135714 -0.005348 -0.024194    3          6
# 대유에이피            1.300000  0.000000  0.337209    5          6
# 이노메트리            0.269231  0.202929  0.147826    3          6
#
# [20 rows x 52 columns]

# %% [markdown]
# ## 없는 애들 특징
# * 23 finance가 다 없는 것 같음, 21도 마찬가지일 듯 이런애들은
# * 1개 - 재고자산 회전률 77 매출액 회전률 1
# * 2개는 - 상장 후 per 1, 활동성2, 성장성 16
# * 3개 - 당좌비율 버리기, 성장성 10, 활동성 12 --> 재고자산이 너무 많이 빔 , 증가율은 비슷
# * 4개 - 증권업임
# * 5개 - PBR 하나 문제있음->자본이 문제인가, 수익성 6개, 당좌비율 2, 부채비율 1, 활동성 8, 매출액증가율 8
# * 6개 - 60개에서 PER PBR EV/EBITDA가 문제가 있음
# * 7개 - 9개가 6개에서와 같이 문제가 존재
# * 8개 - 9개가 6개에서와 같이 문제가 존재
# * 9개 - 3개가 6개와 같이 문제가 동일
# * 11개 - 2개가 문제가 동일함
# * 20개 - 그냥 버려야함

# %%
X_train[X_train['NullCount'] == 20].isnull().sum()
# Out:
# 상장일                   0
# 공모 시가총액               0
# 매출총이익률               16
# 영업이익률                16
# ROE                  16
# 유동비율                 16
# 당좌비율                 16
# 부채비율                 16
# 이자보상배율               16
# 매출채권회전율              16
# 재고자산회전율              16
# 매출액증가율               16
# 영업이익증가율              16
# IPO_PER              16
# IPO_PBR              16
# IPO_EV/EBITDA        16
# 1개월 후 PER            16
# 3개월 후 PER            16
# 1개월 후 PBR            16
# 3개월 후 PBR            16
# 1개월 후 EV/EBITDA      16
# 3개월 후 EV/EBITDA      16
# 1개월 평균 거래량회전율         0
# 1개월 평균 일중변동률          0
# 1개월 평균 개인 매도수량 비중     0
# 1개월 평균 개인 매수수량 비중     0
# 1개월 시가총액회전율           0
# 3개월 평균 거래량회전율         0
# 3개월 평균 일중변동률          0
# 3개월 평균 개인 매도수량 비중     0
# 3개월 평균 개인 매수수량 비중     0
# 3개월 시가총액회전율           0
# 1년전 대비 시장 회전율         0
# 1년 전 대비 시장수익률         0
# 1년 전 대비 광의통화 증감률      0
# 1년 전 대비 고객예탁금 증감률     0
# 1달 후 시장 회전율           0
# 1달 후 시장수익률            0
# 1달 후 광의통화 증감률         0
# 1달 후 고객예탁금 증감률        0
# 3달 후 시장 회전율           0
# 3달 후 시장수익률            0
# 3달 후 광의통화 증감률         0
# 3달 후 고객예탁금 증감률        0
# 상장일 기준 국고3년시장금리       0
# 공모가 대비 1개월 수익률        0
# 공모가 대비 3개월 수익률        0
# 공모가 대비 6개월 수익률        0
# 1_3_수익률               0
# 3_6_수익률               0
# Cat                   0
# NullCount             0
# dtype: int64

# %% [markdown]
# # 예측 상황별로 X_train 나눠서 저장하기 (컬럼 나누기)

# %%
FinalForm.columns
# Out:
# Index(['상장일', '공모 시가총액', '매출총이익률', '유동비율', '부채비율', '매출액증가율', 'IPO_PER',
#        'IPO_PBR', 'IPO_EV/EBITDA', '1개월 후 PER', '3개월 후 PER', '1개월 후 PBR',
#        '3개월 후 PBR', '1개월 후 EV/EBITDA', '3개월 후 EV/EBITDA', '1개월 평균 거래량회전율',
#        '1개월 평균 일중변동률', '1개월 평균 개인 매도수량 비중', '1개월 평균 개인 매수수량 비중', '1개월 시가총액회전율',
#        '3개월 평균 거래량회전율', '3개월 평균 일중변동률', '3개월 평균 개인 매도수량 비중',
#        '3개월 평균 개인 매수수량 비중', '3개월 시가총액회전율', '1년전 대비 시장 회전율', '1년 전 대비 시장수익률',
#        '1년 전 대비 광의통화 증감률', '1년 전 대비 고객예탁금 증감률', '1달 후 시장 회전율', '1달 후 시장수익률',
#        '1달 후 광의통화 증감률', '1달 후 고객예탁금 증감률', '3달 후 시장 회전율', '3달 후 시장수익률',
#        '3달 후 광의통화 증감률', '3달 후 고객예탁금 증감률', '상장일 기준 국고3년시장금리', '공모가 대비 1개월 수익률',
#        '공모가 대비 3개월 수익률', '공모가 대비 6개월 수익률', '1_3_수익률', '3_6_수익률', 'Cat',
#        'NullCount'],
#       dtype='object')

# %%
X_train_Before_IPO = FinalForm.drop(['1개월 후 PER',
       '3개월 후 PER', '1개월 후 PBR', '3개월 후 PBR', '1개월 후 EV/EBITDA',
       '3개월 후 EV/EBITDA', '1개월 평균 거래량회전율', '1개월 평균 일중변동률', '1개월 평균 개인 매도수량 비중',
       '1개월 평균 개인 매수수량 비중', '1개월 시가총액회전율', '3개월 평균 거래량회전율', '3개월 평균 일중변동률',
       '3개월 평균 개인 매도수량 비중', '3개월 평균 개인 매수수량 비중', '3개월 시가총액회전율','1달 후 시장 회전율', '1달 후 시장수익률', '1달 후 광의통화 증감률',
       '1달 후 고객예탁금 증감률', '3달 후 시장 회전율', '3달 후 시장수익률', '3달 후 광의통화 증감률', '1년 전 대비 광의통화 증감률',
       '3달 후 고객예탁금 증감률', '1_3_수익률', '3_6_수익률', 'Cat', 'NullCount', '1년전 대비 시장 회전율'],axis = 1)
X_train_Before_IPO.to_csv('CleanData/X_train_Before_IPO.csv',encoding = 'euc-kr')

# %%
X_train_After_IPO_1 = FinalForm.drop(['IPO_PER', 'IPO_PBR', 'IPO_EV/EBITDA', '3개월 후 PER','3개월 후 PBR','3개월 후 EV/EBITDA','3개월 평균 거래량회전율', '3개월 평균 일중변동률',
       '3개월 평균 개인 매도수량 비중', '3개월 평균 개인 매수수량 비중', '3개월 시가총액회전율',
       '1년전 대비 시장 회전율', '1년 전 대비 시장수익률', '1년 전 대비 광의통화 증감률',
       '1년 전 대비 고객예탁금 증감률','3달 후 시장 회전율', '3달 후 시장수익률', '3달 후 광의통화 증감률','1달 후 광의통화 증감률',
       '3달 후 고객예탁금 증감률','공모가 대비 1개월 수익률', '1개월 시가총액회전율', '공모가 대비 3개월 수익률',
       '공모가 대비 6개월 수익률','3_6_수익률', 'Cat', 'NullCount'],axis = 1)
X_train_After_IPO_1['개인거래비중'] = (X_train_After_IPO_1['1개월 평균 개인 매도수량 비중'] + X_train_After_IPO_1['1개월 평균 개인 매수수량 비중']) /2
X_train_After_IPO_1.drop(['1개월 평균 개인 매도수량 비중','1개월 평균 개인 매수수량 비중'],axis = 1,inplace = True)
X_train_After_IPO_1.to_csv('CleanData/X_train_After_IPO_1.csv',encoding = 'euc-kr')

# %%
X_train_After_IPO_3 = FinalForm.drop(['IPO_PER', 'IPO_PBR', 'IPO_EV/EBITDA','1개월 후 PER','1개월 후 PBR','1개월 후 EV/EBITDA','1개월 평균 거래량회전율', '1개월 평균 일중변동률',
       '1개월 평균 개인 매도수량 비중', '1개월 평균 개인 매수수량 비중', '1개월 시가총액회전율',
       '1년전 대비 시장 회전율', '1년 전 대비 시장수익률', '1년 전 대비 광의통화 증감률',
       '1년 전 대비 고객예탁금 증감률','1달 후 시장 회전율', '1달 후 시장수익률', '1달 후 광의통화 증감률','3달 후 광의통화 증감률',
       '1달 후 고객예탁금 증감률','공모가 대비 1개월 수익률', '3개월 시가총액회전율', '공모가 대비 3개월 수익률', 
       '공모가 대비 6개월 수익률','1_3_수익률', 'Cat', 'NullCount'],axis = 1)
X_train_After_IPO_3['개인거래비중'] = (X_train_After_IPO_3['3개월 평균 개인 매도수량 비중'] + X_train_After_IPO_3['3개월 평균 개인 매수수량 비중']) /2
X_train_After_IPO_3.drop(['3개월 평균 개인 매도수량 비중','3개월 평균 개인 매수수량 비중'],axis = 1,inplace = True)
X_train_After_IPO_3.to_csv('CleanData/X_train_After_IPO_3.csv',encoding = 'euc-kr')

# %% [markdown]
# # 종가 수익률 기준으로 하나 더 만들기

# %%
X_train= pd.read_csv('CleanData/KQ_All_2.csv')
X_train.set_index('종목명',inplace = True)

# %%
X_train_EndPrice_IPO = FinalForm.drop(['IPO_PER',
       'IPO_PBR', 'IPO_EV/EBITDA', '1개월 후 PER', '3개월 후 PER', '1개월 후 PBR',
       '3개월 후 PBR', '1개월 후 EV/EBITDA', '3개월 후 EV/EBITDA', '1개월 평균 거래량회전율',
       '1개월 평균 일중변동률', '1개월 평균 개인 매도수량 비중', '1개월 평균 개인 매수수량 비중', '1개월 시가총액회전율',
       '3개월 평균 거래량회전율', '3개월 평균 일중변동률', '3개월 평균 개인 매도수량 비중','1년 전 대비 광의통화 증감률',
       '3개월 평균 개인 매수수량 비중', '3개월 시가총액회전율','1달 후 시장 회전율', '1달 후 시장수익률',
       '1달 후 광의통화 증감률', '1달 후 고객예탁금 증감률', '3달 후 시장 회전율', '3달 후 시장수익률',
       '3달 후 광의통화 증감률', '3달 후 고객예탁금 증감률', '공모가 대비 1개월 수익률', '1년전 대비 시장 회전율',
       '공모가 대비 3개월 수익률', '공모가 대비 6개월 수익률', '1_3_수익률', '3_6_수익률', 'Cat', 'NullCount'],axis = 1)
X_train_EndPrice_IPO.to_csv('CleanData/X_train_EndPrice_IPO.csv',encoding = 'euc-kr')
